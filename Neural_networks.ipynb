# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashrit77/Python/blob/main/Neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %%
#create your first MLP in keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("/content/diabetes.csv")
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
array = dataset.values

# %%
x = array[:,0:8]
y = array[:,8]

# %%
#Creating the model
model1 = Sequential()
model1.add(Dense(12,input_dim = 8,activation="relu"))
model1.add(Dense(8,activation="relu"))
model1.add(Dense(1,activation="sigmoid"))

# %%
#compile the model
model1.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
#loss shows us how much is the error wrt the predicted value;

# %%
model1.fit(x,y,validation_split=0.33,epochs=250,batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 1s 11ms/step - loss: 9.2698 - accuracy: 0.3658 - val_loss: 5.5006 - val_accuracy: 0.4134
# Epoch 2/250
# 26/26 [==============================] - 0s 4ms/step - loss: 4.5841 - accuracy: 0.4144 - val_loss: 3.6938 - val_accuracy: 0.4449
# Epoch 3/250
# 26/26 [==============================] - 0s 3ms/step - loss: 3.2537 - accuracy: 0.4475 - val_loss: 2.8007 - val_accuracy: 0.4449
# Epoch 4/250
# 26/26 [==============================] - 0s 3ms/step - loss: 2.4644 - accuracy: 0.4786 - val_loss: 2.1421 - val_accuracy: 0.4961
# Epoch 5/250
# 26/26 [==============================] - 0s 3ms/step - loss: 1.9210 - accuracy: 0.5039 - val_loss: 1.7819 - val_accuracy: 0.4882
# Epoch 6/250
# 26/26 [==============================] - 0s 4ms/step - loss: 1.6553 - accuracy: 0.5409 - val_loss: 1.5892 - val_accuracy: 0.4764
# Epoch 7/250
# ...

# %%
scores = model1.evaluate(x,y)
print("%s:%.2f%%" % (model1.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5114 - accuracy: 0.7448
# accuracy:74.48%
